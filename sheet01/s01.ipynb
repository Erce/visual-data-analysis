# %% [markdown]
# # Visual Data Analysis Assignment Sheet 1
#
# >Jan Scheffczyk     3242317<br/>
# >Oliver Leuschner   3205025
#
# #### Excercise 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
tips = sns.load_dataset("tips")

# %% [markdown]
# **a)** Are there days of the week on which the dataset covers only one meal, i.e., either lunch or dinner?

# %%
sns.relplot(x="total_bill", y="day",hue="time", data=tips);

# %% [markdown]
# Yes, Saturdays and Sundays only provide Dinners.
#
# **b)** Was the highest tip given by a man or a woman?
#
# By a man.

# %%
sns.relplot(x="total_bill", y="tip",hue="sex", data=tips);

# %% [markdown]
# **c)** Was the highest tip given for the highest total bill?

# %%
sns.relplot(x="total_bill", y="tip", data=tips);

# %% [markdown]
# Yes.
